# %%
import glob
import dlib
from skimage import io
from scipy.spatial.distance import euclidean

import matplotlib.pyplot as plt

# %%
ls
# Out:
#  ’®¬ ў гбва®©бвўҐ C ­Ґ Ё¬ҐҐв ¬ҐвЄЁ.
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : 169E-08D5
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Users\igor\Data_science\1\face_verification
#
# 18.05.2020  14:09    <DIR>          .
# 18.05.2020  14:09    <DIR>          ..
# 17.05.2020  22:53    <DIR>          .ipynb_checkpoints
# 18.05.2020  13:58    <DIR>          data_base
# 16.05.2020  23:13        22я466я066 dlib_face_recognition_resnet_model_v1.dat
# 18.05.2020  14:08             8я017 face_verification_debag.ipynb
# 18.05.2020  11:08             1я212 main.py
# 18.05.2020  13:42    <DIR>          photo
# 18.05.2020  01:23               263 README.md
# 16.05.2020  23:11        99я693я937 shape_predictor_68_face_landmarks.dat
#                5 д ©«®ў    122я169я495 Ў ©в
#                5 Ї Ї®Є  15я869я538я304 Ў ©в бў®Ў®¤­®

# %%
sp = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
facerec = dlib.face_recognition_model_v1('dlib_face_recognition_resnet_model_v1.dat')
detector = dlib.get_frontal_face_detector()

# %%
pass_to_photo="data_base/fotos/Bred_Pitt.jpg"
pass_to_passport = "data_base/passports/Bred_Pitt.jpg"

# %%
image_photo = io.imread(pass_to_photo)
image_passport = io.imread(pass_to_passport)

# %%
from os.path import basename

# now you can call it directly with basename
print(basename(pass_to_photo))
# Out:
# Bred_Pitt.jpg

# %%
basename(pass_to_photo)
# Out:
# 'Bred_Pitt.jpg'

# %%
name_folder = 'data_base/passports'
name_photo_file = (glob.glob('{0}/*.jpg'.format(name_folder)))
list_names =[i.replace('\\', '/') for i in name_photo_file]

# %%
list_names
# Out:
# ['data_base/passports/Barak_Obama.jpg',
#  'data_base/passports/Bred_Pitt.jpg',
#  'data_base/passports/Donald_Tramp.jpg']

# %%
pattern=basename(pass_to_photo)

# %%
pattern
# Out:
# 'Bred_Pitt.jpg'

# %%
a=[]
a.append(pattern)

# %%
a
# Out:
# ['Bred_Pitt.jpg']

# %%
#работает. Поиск пути по шаблону
def search_pass(list_names, a):
    i = ''
    for i in list_names:
        text = i
        for j in a:
            find = re.search(j, text)
            if find:
                return i

# %%
pass_to_photo = "data_base/fotos/Bred_Pitt.jpg"

# %%
def open_image_web(pass_to_photo):
    ''''''
    name_image = []
    image_photo_web = io.imread(pass_to_photo)
    name = basename(pass_to_photo)
    name_image.append(name)
    return image_photo, name_image

# %%
plt.figure(figsize = (5,7))
plt.imshow(image_photo , aspect='auto') # view image
plt.show()

# %%
plt.figure(figsize = (5,7))
plt.imshow(image_photo_web , aspect='auto') # view image
plt.show()

# %%
name_image_web = []
image_photo_web = io.imread(pass_to_photo)
name = basename(pass_to_photo)
name_image_web.append(name)

name_image_passport = []
image_photo_web = io.imread(pass_to_passport)
name = basename(pass_to_passport)
name_image_passport.append(name)

# %%
name_image_web
# Out:
# ['Bred_Pitt.jpg']

# %%
name_image_passport
# Out:
# ['Bred_Pitt.jpg']

# %%
list_images=[]

# %%
list_images.append(name_image_web[0])
list_images.append(name_image_passport[0])

# %%
list_images
# Out:
# ['Bred_Pitt.jpg', 'Bred_Pitt.jpg']

# %%
rects = []
shapes=[]
descriptors=[]

# %%
detect_photo = detector(image_photo, 1)
rects.append(detect_photo[0])
shape = sp(image_photo, detect_photo[0])
shapes.append(shape)    
face_desc = facerec.compute_face_descriptor(image_photo, shape)
descriptors.append(face_desc)

# %%
detect_photo = detector(image_photo, 1)
rects.append(detect_photo[0])
shape = sp(image_photo, detect_photo[1])
shapes.append(shape)    
face_desc = facerec.compute_face_descriptor(image_photo, shape)
descriptors.append(face_desc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-630-2a242e66416c> in <module>
#       1 detect_photo = detector(image_photo, 1)
#       2 rects.append(detect_photo[0])
# ----> 3 shape = sp(image_photo, detect_photo[1])
#       4 shapes.append(shape)
#       5 face_desc = facerec.compute_face_descriptor(image_photo, shape)
#
# IndexError:

# %%
euclidean(descriptors[0], descriptors[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-631-4e2acb2911ab> in <module>
# ----> 1 euclidean(descriptors[0], descriptors[1])
#
# IndexError: list index out of range

# %%
search_pass(list_names, a)
# Out:
# 'data_base/passports/Bred_Pitt.jpg'

# %%
search_text = ['Barak']
age = [i for i in list_names if search_text[0] in i.lower()]

# %%
age
# Out:
# []

# %%
search_text = 'Barak_Obama'
age = [i for i in list_names if search_text]

# %%
prefix = 'data_base/passports/Barak_Obama.jpg'
# newlst = filter(lambda s: s[0] == prefix[0] and s[1] == prefix[1], list_names)

# %%
newlst = list(filter(lambda x: x == prefix, list_names))

# %%
print(newlst)
# Out:
# ['data_base/passports/Barak_Obama.jpg']

# %%
name_photo_file = glob.glob('*.jpg')

# %%
name_photo_file
# Out:
# []

# %%
list_names = [i.replace('\\', '/') for i in name_photo_file]

# %%
def list_image(image_photo_web, image_photo_passport):

# %%
rects = []
shapes=[]
descriptors=[]
for photo in list_names:
    image_photo = io.imread(photo)
    
    detect_photo = detector(image_photo, 1)
    rects.append(detect_photo[0])
    
    shape = sp(image_photo, detect_photo[0])
    shapes.append(shape)
    
    face_desc = facerec.compute_face_descriptor(image_photo, shape)
    descriptors.append(face_desc)

# %%
print(' {0}'.format(euclidean(descriptors[0], descriptors[1])))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-617-b2c45564e8d3> in <module>
# ----> 1 print(' {0}'.format(euclidean(descriptors[0], descriptors[1])))
#
# IndexError: list index out of range

# %%
euclidean(descriptors[0], descriptors[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-616-4e2acb2911ab> in <module>
# ----> 1 euclidean(descriptors[0], descriptors[1])
#
# IndexError: list index out of range

# %%
rects
# Out:
# [rectangle(502,428,1167,1094), rectangle(86,574,175,664)]

# %%
win = dlib.image_window()
win.add_overlay(rects[0])
win.add_overlay(shapes[0])
win.set_image(io.imread(list_names[0]))

# %%
win = dlib.image_window()
win.add_overlay(rects[1])
win.add_overlay(shapes[1])
win.set_image(io.imread(list_names[1]))

# %%
win.set_image(io.imread(list_names[1]))

# %%
win

# %%
def decision_making(euclidean_distance):
    if euclidean_distance < 0.6:
        return print("Verification Passed")
    else:
        return print("Verification not Passed !!!!")

# %%
decision_making(0.69)
# Out:
# Verification not Passed !!!!

# %%
def printPetNames(owner, **pets):
   print("Owner Name: {owner}")
   for pet,name in pets.items():
      print(f"{pet}: {name}")

# %%
printPetNames("Jonathan", dog="Brock", fish=["Larry", "Curly", "Moe"], turtle="Shelldon")
# Out:
# Owner Name: {owner}
# dog: Brock
# fish: ['Larry', 'Curly', 'Moe']
# turtle: Shelldon

# %%
import re

# %%
re.search('Barak', list_names[0])
# Out:
# <_sre.SRE_Match object; span=(20, 25), match='Barak'>

# %%
list_names
# Out:
# ['data_base/passports/Barak_Obama.jpg',
#  'data_base/passports/Bred_Pitt.jpg',
#  'data_base/passports/Donald_Tramp.jpg']

# %%
dearch(list_names, ['Barak'])
# Out:
# 'data_base/passports/Barak_Obama.jpg'

# %%
text = list_names[1]
patterns = ['Barak']

for i in patterns:
    find = re.search(i, text)
    if find:
        print('Found "{}" in "{}"'.format(i, text))
    else:
        print('Did not find "{}"'.format(i))
# Out:
# Did not find "Barak"

# %%
find = re.search(pattern, text)

# %%
list_names
# Out:
# ['data_base/passports/Barak_Obama.jpg',
#  'data_base/passports/Bred_Pitt.jpg',
#  'data_base/passports/Donald_Tramp.jpg']

# %%
b = set(list_names)
print(b)
# Out:
# {'data_base/passports/Barak_Obama.jpg', 'data_base/passports/Bred_Pitt.jpg', 'data_base/passports/Donald_Tramp.jpg'}

# %%
''.join('ololo')
# Out:
# 'ololo'
